# %%
import seaborn as sns
from math import log2
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure

# %%
run_time = [29.77, 24.43, 28.68, 52.64, 75.44, 113.8, 185, 345.6, 569.6, 1173]
run_time = [log(x) for x in run_time]

x_val = [1.25, 2.5, 5, 10, 20, 40, 80, 160, 320, 640]
x_val = list(range(10))

graph = sns.lineplot(x=x_val, y =run_time)
graph.set_xlabel("2$^{scale-factor}$", fontsize = 20)
graph.set_ylabel("time (seconds)", fontsize = 20)
# Out:
# Text(0, 0.5, 'time (seconds)')

# %%
run_time = [29.77, 24.43, 28.68, 52.64, 75.44, 113.8, 185, 345.6, 569.6, 1173]
#run_time = [log(x) for x in run_time]

x_val = [1.25, 2.5, 5, 10, 20, 40, 80, 160, 320, 640]
x_val = list(range(10))

graph = sns.lineplot(x=x_val, y =run_time)
graph.set_xlabel("2$^{scale-factor}$", fontsize = 20)
graph.set_ylabel("time (seconds)", fontsize = 20)
# Out:
# Text(0, 0.5, 'time (seconds)')

# %%
run_time = [29.77, 24.43, 28.68, 52.64, 75.44, 113.8, 185, 345.6, 569.6, 1173]
run_time = [x/run_time[0] for x in run_time]

x_val = [1.25, 2.5, 5, 10, 20, 40, 80, 160, 320, 640]
x_val = [2**i for i in range(10)]

graph = sns.lineplot(x=x_val, y =run_time)
graph.set_title('time vs datasize', fontsize = 20)
graph.set_xlabel("relative size (gbs)", fontsize = 20)
graph.set_ylabel("time", fontsize = 20)
ax.set_xticklabels([f'{i}x' for i in run_time])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27880/2235532227.py in <module>
#       9 graph.set_xlabel("relative size (gbs)", fontsize = 20)
#      10 graph.set_ylabel("time", fontsize = 20)
# ---> 11 ax.set_xticklabels([f'{i}x' for i in run_time])
#
# NameError: name 'ax' is not defined

# %%
initial = 29.77
run_time = [29.77, 24.43, 28.68, 52.64, 75.44, 113.8, 185, 345.6, 569.6, 1173]
run_time = [x/run_time[0] for x in run_time]

#x_val = [20, 40, 80, 160, 320, 640]
x_val = [2**i for i in range(10)]

fig, ax = plt.subplots()
graph = sns.lineplot(x=x_val, y =run_time)
graph.set_title('Time vs Datasize', fontsize = 20)
graph.set_xlabel("Relative Size", fontsize = 20)
graph.set_ylabel("Time", fontsize = 20)
fig.set_size_inches(20,10, forward=True)
tmp = [1,16,32,64,128,256,512]
ax.set_xticklabels([f'{i}x' for i in tmp])
ax.set_xticks(tmp)
# Out:
# C:\Users\emani\AppData\Local\Temp/ipykernel_27880/23205232.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([f'{i}x' for i in tmp])
# ...

# %%
initial = 29.77
run_time = [29.77, 24.43, 28.68, 52.64, 75.44, 113.8, 185, 345.6, 569.6, 1173]
run_time = [log2(x/run_time[0]) for x in run_time]

#x_val = [20, 40, 80, 160, 320, 640]
x_val = [i for i in range(10)]

fig, ax = plt.subplots()
graph = sns.lineplot(x=x_val, y =run_time)
graph.set_title('Time vs Datasize', fontsize = 20)
graph.set_xlabel("Relative Size", fontsize = 20)
graph.set_ylabel("Time", fontsize = 20)
fig.set_size_inches(20,10, forward=True)
tmp = [1,16,32,64,128,256,512]
ax.set_xticklabels([f'{i}x' for i in tmp])
#ax.set_xticks(tmp)
# Out:
# C:\Users\emani\AppData\Local\Temp/ipykernel_27880/96770732.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([f'{i}x' for i in tmp])
# [Text(-2.0, 0, '1.0x'),
#  Text(0.0, 0, '4.087462841250339x'),
#  Text(2.0, 0, '5.044394119358453x'),
#  Text(4.0, 0, '6.022367813028454x'),
#  Text(6.0, 0, '7.011227255423254x'),
#  Text(8.0, 0, '8.005624549193879x'),
#  Text(10.0, 0, '9.002815015607053x')]

# %%
initial = 29.77
run_time = [29.77, 24.43, 28.68, 52.64, 75.44, 113.8, 185, 345.6, 569.6, 1173]
run_time = [log2(x/run_time[0]) for x in run_time]

#x_val = [20, 40, 80, 160, 320, 640]
x_val = [i for i in range(10)]

fig, ax = plt.subplots()
graph = sns.lineplot(x=x_val, y =run_time)
graph.set_title('Time vs Datasize', fontsize = 20)
graph.set_xlabel("relative size", fontsize = 20)
graph.set_ylabel("time", fontsize = 20)
fig.set_size_inches(20,10, forward=True)

tmp = [1,16,32,64,128,256,512]
ax.set_xticklabels([f'{i}x' for i in tmp])
ax.set_xticks(tmp)
tmp = [log2(i+1) for i in tmp]
#run_time = [29.77, 75.44, 113.8, 185, 345.6, 569.6, 1173]
tmp2 = [log2(i) for i in tmp]
ax.set_yticks(tmp2)
# Out:
# C:\Users\emani\AppData\Local\Temp/ipykernel_27880/3503914446.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([f'{i}x' for i in tmp])
# ...
